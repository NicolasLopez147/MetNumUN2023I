# %% [markdown]
# ![nilopezncognitiveclassaapplieddatadciencewithpython.png](data:image/png;base64,...)

# %% [markdown]
# **Link de linkedin** https://www.linkedin.com/in/nicolas-lopez-nieto-771118268/
